# %%
import pandas as pd
import os
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from pathlib import Path

data_path = '/home/ubuntu/landscape-aesthetics/data/external/scenicornot/scenicornot.metadata.csv'
image_folder = Path('/home/ubuntu/landscape-aesthetics/data/external/scenicornot') 

# Check if the data path exists
if not os.path.exists(data_path):
    raise FileNotFoundError(f"Data file not found at {data_path}")

#read dataset
data = pd.read_csv(data_path)

# Check if the root directory exists
root_dir = '/home/ubuntu/landscape-aesthetics/data/external/scenicornot/'
if not os.path.exists(root_dir):
    raise FileNotFoundError(f"Root directory not found at {root_dir}")

# 预处理数据集，移除无效路径
valid_files = []
missing_files = []
for idx in range(len(data)):
    img_name = data.iloc[idx]['filename']
    image_path = image_folder / Path(img_name)
    if image_path.exists():
        valid_files.append(idx)
    else:
        missing_files.append(image_path)

if missing_files:
    print(f"Missing {len(missing_files)} files:")
    for file in missing_files:
        print(file)

# 只保留有效的文件记录
valid_data = data.iloc[valid_files].reset_index(drop=True)

class ScenicDataset(Dataset):
    def __init__(self, data_frame, root_dir, transform=None):
        self.data_frame = data_frame
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.root_dir, self.data_frame.iloc[idx]['filename']) # combine root address with filename
        image_path = self.root_dir / Path(img_name)
        print(f"Loading image: {image_path}")  # 调试信息，打印图片路径

        try:
            image = Image.open(image_path).convert('RGB')
        except FileNotFoundError:
            print(f"File not found: {image_path}, skipping.")
            return None, None
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
            return None, None
            
        rating = self.data_frame.iloc[idx]['average']
        
        if self.transform:
            image = self.transform(image)

        return image, torch.tensor(rating, dtype=torch.float32)

# centered crop 256*256
data_transforms = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(256),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
])

# Create the dataset
image_dataset = ScenicDataset(data_frame=valid_data,
                              root_dir=image_folder,
                              transform=data_transforms)

# Split the dataset into training and validation sets
train_size = int(0.8 * len(image_dataset))
val_size = len(image_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(image_dataset, [train_size, val_size])

# Create data loaders
def collate_fn(batch):
    batch = list(filter(lambda x: x[0] is not None and isinstance(x[0], torch.Tensor), batch))
    return torch.utils.data.dataloader.default_collate(batch)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Print the sizes of the training and validation set
print(f"Training set size: {len(train_loader.dataset)}")
print(f"Validation set size: {len(val_loader.dataset)}")
# Out:
# Missing 1 files:
# /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/76/41/764143_e860c8c4.jpg
# Training set size: 169484
# Validation set size: 42371

# %%
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms

# utilise ResNet50 to extract deep features
class ResNetFeatureExtractor(nn.Module):
    def __init__(self):
        super(ResNetFeatureExtractor, self).__init__()
        self.resnet = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1)
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])  # Remove the last fully connected layer

    def forward(self, x):
        with torch.no_grad():
            features = self.resnet(x)
        return features.squeeze()

feature_extractor = ResNetFeatureExtractor()
feature_extractor.eval()

# define a simple regression model
class RegressionModel(nn.Module):
    def __init__(self, input_dim):
        super(RegressionModel, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 1)
        )

    def forward(self, x):
        return self.fc(x)

# a more complex one
# class RegressionModel(nn.Module):
#     def __init__(self, input_dim):
#         super(ComplexRegressionModel, self).__init__()
#         self.fc = nn.Sequential(
#             nn.Linear(input_dim, 512),
#             nn.ReLU(),
#             nn.BatchNorm1d(512),
#             nn.Dropout(0.5),
#             nn.Linear(512, 256),
#             nn.ReLU(),
#             nn.BatchNorm1d(256),
#             nn.Dropout(0.5),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.BatchNorm1d(128),
#             nn.Dropout(0.5),
#             nn.Linear(128, 1)
#         )
        
#     def forward(self, x):
#         return self.fc(x)

# %%
import matplotlib.pyplot as plt

def train_model(feature_extractor, model, criterion, optimizer, scheduler, train_loader, val_loader, num_epochs=10):
    train_losses = []
    val_losses = []
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        
        for images, labels in train_loader:
            if images is None:  # skip invalid images
                    continue
            features = feature_extractor(images).view(images.size(0), -1)# 添加 .view 以确保特征形状正确
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs.squeeze(), labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)
        print(f'Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss}')
        
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for images, labels in val_loader:
                if images is None:  # skip invalid images
                    continue
                features = feature_extractor(images).view(images.size(0), -1)
                outputs = model(features)
                loss = criterion(outputs.squeeze(), labels)
                val_loss += loss.item() * images.size(0)
        
        val_loss /= len(val_loader.dataset)
        val_losses.append(val_loss)
        print(f'Validation Loss: {val_loss}')
        
        scheduler.step()  # Update learning rate
    
    return train_losses, val_losses


# Initialize feature extractor and regression model
feature_extractor = ResNetFeatureExtractor()
feature_extractor.eval()  # Set the feature extractor to evaluation mode
input_dim = 2048  # ResNet50 feature dimension
model = RegressionModel(input_dim)

# Define loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)  # Learning rate scheduler

# training model
train_losses, val_losses = train_model(feature_extractor, model, criterion, optimizer, scheduler, train_loader, val_loader, num_epochs=10)

# Plot training and validation loss
plt.figure()
plt.plot(range(10), train_losses, label='Training Loss')
plt.plot(range(10), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/09/13/091316_c1197277.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/09/87/1098776_27e135a3.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/83/63/836301_f7e72581.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/66/82/668243_504d3489.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/18/81/188132_1bb99995.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/77/29/772986_26e5035a.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/31/63/316350_3296281f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/97/03/970313_f87a8e07.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/65/25/652550_11138434.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/14/94/1149402_10e9c680.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/84/28/842803_5da1361c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/88/36/883616_0a969561.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/79/01/790197_b16cd175.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/04/47/1044786_027919ed.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/09/19/1091901_1ef7925c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/85/33/853396_fd5df9c4.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/93/86/938618_cbda137f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/01/99/1019990_7a46baf4.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/12/84/128426_f1f899e3.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/54/58/545818_a09089fc.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/64/93/649342_3acfdc68.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/72/22/722286_ac699f93.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/63/34/633409_ed82a571.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/88/81/888100_26929006.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/19/02/190292_88a6d400.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/06/43/064316_3c29c5d8.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/04/15/041516_6bb28eef.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/07/49/1074938_d4867ebe.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/13/18/131896_9c7ce162.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/79/11/791192_190d10de.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/22/54/225459_d7cc0b1e.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/34/45/344567_a5104381.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/56/78/567825_67fcd058.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/02/91/029169_031709b9.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/69/56/695671_34860e48.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/37/61/376180_f4052b1d.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/83/12/831296_0db7f8bc.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/39/46/394657_85ada45f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/08/70/1087077_fb4723d8.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/39/83/398305_f6f857e9.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/59/61/596105_27c45b6e.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/63/05/630546_b40ab15c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/03/22/032214_4ba771d9.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/16/67/166749_1a65af3d.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/16/15/161573_6045b897.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/54/85/548576_6f1ad08c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/09/55/1095513_f4c099e0.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/39/84/398428_94927056.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/07/38/1073899_3d5f66a5.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/91/72/917270_84f86cce.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/04/40/1044011_251e342c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/45/01/450193_f537ac78.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/79/34/793463_3c5a07fe.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/11/31/113141_2569d841.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/16/30/163059_3f539b39.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/35/01/350174_a2e8dfaf.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/50/61/506102_f7097c39.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/66/34/663444_94fc3dcb.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/74/81/748188_a3641dd5.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/93/16/931633_0ec5c1e5.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/46/79/467935_071ff630.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/17/34/173466_d26a014d.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/89/38/893848_409cc1a7.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos
jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/93/35/933560_9b54f331.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/12/96/129653_2665a52f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/53/53/535310_00053379.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/08/87/088733_05d41487.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/66/34/663464_feab3c68.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/10/66/106621_83df59df.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/17/07/170752_9f940703.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/60/14/601464_43516078.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/09/02/090246_36ee0212.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/03/00/030093_ba6bdc38.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/82/93/829385_ecab0f76.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/69/46/694673_90f69d67.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/20/28/202838_9fb75985.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/59/33/593312_4886b374.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/95/65/956588_e29400b0.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/21/98/219899_de2625a7.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/99/46/994687_e0d10d1e.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/06/97/1069702_96d53246.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/86/38/863861_a92e925f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/72/91/729162_f17ead3a.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/10/66/106646_cc13993f.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/00/25/1002500_69035a9c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/66/50/665058_8abc1764.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/15/74/157490_16aca189.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/25/76/257652_d8b8076e.jpg
# Error loading image /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/25/76/257652_d8b8076e.jpg: image file is truncated (0 bytes not processed)
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/99/03/990377_9a3f7ba2.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/79/24/792412_3deed3d3.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/08/79/087951_0bfaada5.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/62/36/623680_2906416b.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/11/88/1118853_012ae287.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/04/86/1048631_bc81a175.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/28/55/285554_15d9ccbe.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/77/37/773758_077946a0.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/19/37/193706_801eaae6.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/geophotos/01/13/33/1133388_c76590e9.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/59/19/591950_7fb73443.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/41/36/413679_40f16d43.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/49/89/498968_e52a990b.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/57/31/573116_493d9123.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/40/42/404221_1331482c.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/26/76/267642_8f3fdee3.jpg
# Loading image: /home/ubuntu/landscape-aesthetics/data/external/scenicornot/photos/30/83/308393_9c3549be.jpg
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 57
#      54 scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)  # Learning rate scheduler
#      56 # training model
# ---> 57 train_losses, val_losses = train_model(feature_extractor, model, criterion, optimizer, scheduler, train_loader, val_loader, num_epochs=10)
#      59 # Plot training and validation loss
#      60 plt.figure()
#
# Cell In[23], line 10, in train_model(feature_extractor, model, criterion, optimizer, scheduler, train_loader, val_loader, num_epochs)
#       7 model.train()
#       8 running_loss = 0.0
# ---> 10 for images, labels in train_loader:
#      11     if images is None:  # skip invalid images
#      12             continue
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:316, in default_collate(batch)
#     255 def default_collate(batch):
#     256     r"""
#     257     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     258
#    (...)
#     314         >>> default_collate(batch)  # Handle `CustomType` automatically
#     315     """
# --> 316     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:173, in collate(batch, collate_fn_map)
#     170 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     172 if isinstance(elem, tuple):
# --> 173     return [collate(samples, collate_fn_map=collate_fn_map) for samples in transposed]  # Backwards compatibility.
#     174 else:
#     175     try:
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:141, in collate(batch, collate_fn_map)
#     139 if collate_fn_map is not None:
#     140     if elem_type in collate_fn_map:
# --> 141         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     143     for collate_type in collate_fn_map:
#     144         if isinstance(elem, collate_type):
#
# File ~/anaconda3/envs/geoproject/lib/python3.12/site-packages/torch/utils/data/_utils/collate.py:213, in collate_tensor_fn(batch, collate_fn_map)
#     211     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     212     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 213 return torch.stack(batch, 0, out=out)
#
# TypeError: expected Tensor as element 14 in argument 0, but got NoneType

# %%
# evaluate
def evaluate_model(feature_extractor, model, test_loader):
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            features = feature_extractor(images).view(images.size(0), -1)
            outputs = model(features)
            loss = criterion(outputs.squeeze(), labels)
            test_loss += loss.item() * images.size(0)
    
    test_loss /= len(test_loader.dataset)
    print(f'Test Loss: {test_loss}')
    return test_loss

# # save the model
# torch.save(model.state_dict(), 'complex_regression_model.pth')
# print("Model saved to complex_regression_model.pth")
